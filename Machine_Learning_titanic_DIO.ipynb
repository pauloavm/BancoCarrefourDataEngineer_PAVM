# %% [markdown]
# <a href="https://colab.research.google.com/github/pauloavm/BancoCarrefourDataEngineer_PAVM/blob/main/Machine_Learning_titanic_DIO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
dados = pd.read_csv('/content/train.csv')

# %%
dados.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0          892         0       3  ...   7.8292   NaN         Q
# 1          893         1       3  ...   7.0000   NaN         S
# 2          894         0       2  ...   9.6875   NaN         Q
# 3          895         0       3  ...   8.6625   NaN         S
# 4          896         1       3  ...  12.2875   NaN         S
#
# [5 rows x 12 columns]

# %%
dados = dados.drop(['Name' , 'Ticket' , 'Cabin' , 'Embarked'], axis =1)

# %%
dados.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0          892         0       3    male  34.5      0      0   7.8292
# 1          893         1       3  female  47.0      1      0   7.0000
# 2          894         0       2    male  62.0      0      0   9.6875
# 3          895         0       3    male  27.0      0      0   8.6625
# 4          896         1       3  female  22.0      1      1  12.2875

# %%
dados = dados.rename(columns= {'Survived': 'target'})

# %%
dados.head()
# Out:
#    PassengerId  target  Pclass     Sex   Age  SibSp  Parch     Fare
# 0          892       0       3    male  34.5      0      0   7.8292
# 1          893       1       3  female  47.0      1      0   7.0000
# 2          894       0       2    male  62.0      0      0   9.6875
# 3          895       0       3    male  27.0      0      0   8.6625
# 4          896       1       3  female  22.0      1      1  12.2875

# %%
dados.describe()
# Out:
#        PassengerId      target      Pclass  ...       SibSp       Parch        Fare
# count   418.000000  418.000000  418.000000  ...  418.000000  418.000000  417.000000
# mean   1100.500000    0.363636    2.265550  ...    0.447368    0.392344   35.627188
# std     120.810458    0.481622    0.841838  ...    0.896760    0.981429   55.907576
# min     892.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     996.250000    0.000000    1.000000  ...    0.000000    0.000000    7.895800
# 50%    1100.500000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%    1204.750000    1.000000    3.000000  ...    1.000000    0.000000   31.500000
# max    1309.000000    1.000000    3.000000  ...    8.000000    9.000000  512.329200
#
# [8 rows x 7 columns]

# %%
dados.describe(include=['O'])
# Out:
#          Sex
# count    418
# unique     2
# top     male
# freq     266

# %%
dados['Sex_F'] = np.where(dados['Sex'] == 'female', 1, 0)

dados['Pclass_1'] = np.where(dados['Pclass'] == 1, 1, 0)
dados['Pclass_2'] = np.where(dados['Pclass'] == 2, 1, 0)
dados['Pclass_3'] = np.where(dados['Pclass'] == 3, 1, 0)

# %%
dados = dados.drop(['Pclass', 'Sex'], axis = 1)

# %%
dados.head()
# Out:
#    PassengerId  target   Age  SibSp  ...  Sex_F  Pclass_1  Pclass_2  Pclass_3
# 0          892       0  34.5      0  ...      0         0         0         1
# 1          893       1  47.0      1  ...      1         0         0         1
# 2          894       0  62.0      0  ...      0         0         1         0
# 3          895       0  27.0      0  ...      0         0         0         1
# 4          896       1  22.0      1  ...      1         0         0         1
#
# [5 rows x 10 columns]

# %%
dados.isnull().sum()
# Out:
# PassengerId     0
# target          0
# Age            86
# SibSp           0
# Parch           0
# Fare            1
# Sex_F           0
# Pclass_1        0
# Pclass_2        0
# Pclass_3        0
# dtype: int64

# %%
dados.fillna(0, inplace=True)

# %%
dados.isnull().sum()
# Out:
# PassengerId    0
# target         0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Sex_F          0
# Pclass_1       0
# Pclass_2       0
# Pclass_3       0
# dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(dados.drop(['target'], axis=1),
                                                    dados["target"],
                                                    test_size = 0.3,
                                                    random_state = 1234)
[{'treino': x_train.shape},
 {'teste': x_test.shape}]
# Out:
# [{'treino': (292, 9)}, {'teste': (126, 9)}]

# %%
rndforest = RandomForestClassifier(n_estimators=1000,
                                   criterion='gini',
                                   max_depth=5)
rndforest.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, n_estimators=1000)

# %%
probabilidade = rndforest.predict_proba(dados.drop('target', axis = 1))[:,1]
classificacao = rndforest.predict(dados.drop('target', axis = 1))

# %%
dados['probabilidade'] = probabilidade
dados['classificacao'] = classificacao

# %%
dados
# Out:
#      PassengerId  target   Age  ...  Pclass_3  probabilidade  classificacao
# 0            892       0  34.5  ...         1       0.079826              0
# 1            893       1  47.0  ...         1       0.962640              1
# 2            894       0  62.0  ...         0       0.047640              0
# 3            895       0  27.0  ...         1       0.056014              0
# 4            896       1  22.0  ...         1       0.957214              1
# ..           ...     ...   ...  ...       ...            ...            ...
# 413         1305       0   0.0  ...         1       0.027235              0
# 414         1306       1  39.0  ...         0       0.960307              1
# 415         1307       0  38.5  ...         1       0.022795              0
# 416         1308       0   0.0  ...         1       0.027235              0
# 417         1309       0   0.0  ...         1       0.051714              0
#
# [418 rows x 12 columns]
